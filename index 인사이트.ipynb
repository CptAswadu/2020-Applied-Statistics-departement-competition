# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_location = 'C:/Windows/Fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname = font_location).get_name()
rc('font', family=font_name)
from scipy.spatial.distance import euclidean

import dtw

# %%
index_data = pd.read_csv('C:/Users/cptas/공모전/index.csv')

# %%
def masking(df,age,gender):
    mask1 = (df['sigungu'] == "all")
    mask2 = (df['gender'] == gender)
    mask3 = (df['age'].isin(age))
    
    df1 = df.loc[mask1]
    df2 = df1.loc[mask2]
    df3 = df2.loc[mask3]
    
    df3 = df3.groupby(['period','catm']).mean().reset_index()
    data_pivot = df3.pivot(index='period',columns='catm',values='cgi').fillna(0)
    data_pivot_insert = pd.DataFrame(np.repeat(100,17)).T
    data_pivot_insert.columns = list(data_pivot.columns)
    data_pivot = pd.concat([data_pivot_insert, data_pivot])
    
    return data_pivot

# %%
index_summarise = masking(index_data, age=['20', '30', '40'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['all'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "2040F")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "all")

# %%
index_summarise1 = masking(index_data, age=['all'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(4, 4, figsize=(15, 30))
ax = ax.ravel()
for i in range(len(ax)):
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')

# %%
#20대 남성
index_summarise = masking(index_data, age=['20'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['all'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "20M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "all")

# %%
#20대 여성
index_summarise = masking(index_data, age=['20'], gender='F')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['all'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "20F")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "all")

# %%
#20대 남성, 여성 비교
index_summarise = masking(index_data, age=['20'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['20'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "20M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "20F")

# %%
#30대 남성, 여성 비교
index_summarise = masking(index_data, age=['30'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['30'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "30M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "30F")

# %%
#40대 남성, 여성 비교
index_summarise = masking(index_data, age=['40'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['40'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "40M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "40F")

# %%
#50대 남성, 여성 비교
index_summarise = masking(index_data, age=['50'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['50'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "50M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "50F")

# %%
#60대 남성, 여성 비교
index_summarise = masking(index_data, age=['60'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['60'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "60M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "60F")

# %%
#연령대별 비교
index_summarise = masking(index_data, age=['20'], gender='all')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['30'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

index_summarise2 = masking(index_data, age=['40'], gender='all')

index_pivot_bf2 = index_summarise2.iloc[1:6, :]
index_pivot_af2 = index_summarise2.iloc[-5:, :]

index_summarise3 = masking(index_data, age=['50'], gender='all')

index_pivot_bf3 = index_summarise3.iloc[1:6, :]
index_pivot_af3 = index_summarise3.iloc[-5:, :]

index_summarise4 = masking(index_data, age=['60'], gender='all')

index_pivot_bf4 = index_summarise4.iloc[1:6, :]
index_pivot_af4 = index_summarise4.iloc[-5:, :]

index_summarise5 = masking(index_data, age=['all'], gender='all')

index_pivot_bf5 = index_summarise5.iloc[1:6, :]
index_pivot_af5 = index_summarise5.iloc[-5:, :]

fig, ax = plt.subplots(16, 6, figsize=(15, 30))
ax = ax.ravel()


for i in range(len(ax)):
    if i % 6 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/6)] + "20대")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')
        
    if i % 6 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/6)] + "30대")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')
    
    if i % 6 == 2:
        ax[i].plot(np.array(index_pivot_bf2.iloc[:, int((i-2)/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af2.iloc[:, int((i-2)/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf2.columns[int((i-2)/6)] + "40대")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')
        
    if i % 6 == 3:
        ax[i].plot(np.array(index_pivot_bf3.iloc[:, int((i-3)/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af3.iloc[:, int((i-3)/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf3.columns[int((i-3)/6)] + "50대")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')
        
    if i % 6 == 4:
        ax[i].plot(np.array(index_pivot_bf4.iloc[:, int((i-4)/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af4.iloc[:, int((i-4)/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf4.columns[int((i-4)/6)] + "60대")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')
        
    if i % 6 == 5:
        ax[i].plot(np.array(index_pivot_bf5.iloc[:, int((i-5)/6)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af5.iloc[:, int((i-5)/6)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf5.columns[int((i-5)/6)] + "전체평균")
        ax[i].xlabel('기간')
        ax[i].ylabel('카테고리성장지수')

# %%
#50대 남성, 여성 비교
index_summarise = masking(index_data, age=['all'], gender='M')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['all'], gender='F')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "F")

# %%
#20대 남성, 여성 비교
index_summarise = masking(index_data, age=['all'], gender='all')

index_pivot_bf = index_summarise.iloc[1:6, :]
index_pivot_af = index_summarise.iloc[-5:, :]

index_summarise1 = masking(index_data, age=['20'], gender='all')

index_pivot_bf1 = index_summarise1.iloc[1:6, :]
index_pivot_af1 = index_summarise1.iloc[-5:, :]

fig, ax = plt.subplots(8, 4, figsize=(15, 30))
ax = ax.ravel()

for i in range(len(ax)):
    if i % 2 == 0:
        ax[i].plot(np.array(index_pivot_bf.iloc[:, int(i/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af.iloc[:, int(i/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf.columns[int(i/2)] + "20M")
        
    if i % 2 == 1:
        ax[i].plot(np.array(index_pivot_bf1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='before')
        ax[i].plot(np.array(index_pivot_af1.iloc[:, int((i-1)/2)]),marker='o', linewidth=2,label='after')
        ax[i].axhline(y=100, color='r')
        ax[i].set_title(index_pivot_bf1.columns[int((i-1)/2)] + "20F")

# %%
index_data.head()
# Out:
#    period     catl    catm age gender sido sigungu         cgi
# 0  201901  건강/의료용품  건강관리용품  20      F   서울     관악구  115.374642
# 1  201901  건강/의료용품  건강관리용품  20      F   서울     광진구  119.596454
# 2  201901  건강/의료용품  건강관리용품  20      F   서울     도봉구  156.992847
# 3  201901  건강/의료용품  건강관리용품  20      F   서울     동작구   58.342726
# 4  201901  건강/의료용품  건강관리용품  20      F   서울     마포구  145.147595

# %%
index_all = masking(index_data, age=['all'], gender='all')
index_all.head()
# Out:
# catm          가공식품      건강관리용품       기타화장품        기호식품          담배  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  117.570919   93.148223   65.649751  130.918672  131.342473
# 201902   90.337742   92.512090   66.529774   92.947207  110.354433
# 201903   99.831365  100.966480   74.273981   84.755852  129.183434
# 201904   95.224058   85.414640  119.507187   91.554333  126.350291
#
# catm       바디/헤어용품        뷰티소품         빙과류          빵류        생활용품  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  123.402292   72.578396   67.233311  112.092340  101.262282
# 201902   80.209887   70.408716   74.679920   93.130189   88.412436
# 201903   86.816300   82.202584   74.811717  112.942321  104.941775
# 201904   90.300217   67.264532   78.662935  105.543371   94.024466
#
# catm          신선식품      애완동물용품        유제품류          음료         제과류  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  117.382902   90.613278   99.932399   95.525036   98.434326
# 201902   96.874609   86.692108   89.308358   84.031689   99.899524
# 201903  104.294700   96.404626  105.774862   94.838410  110.844999
# 201904   98.019807   86.989560   98.680470   96.685220   98.216421
#
# catm            주류         화장품
# 0       100.000000  100.000000
# 201901  104.588828  104.882519
# 201902   93.363184   81.691496
# 201903   95.855243   90.176158
# 201904   89.179150   81.120077

# %%
index_b = index_all[1:14]
index_c = index_all[14:]

# %%
index_b
# Out:
# catm          가공식품      건강관리용품       기타화장품        기호식품          담배  \
# 201901  117.570919   93.148223   65.649751  130.918672  131.342473
# 201902   90.337742   92.512090   66.529774   92.947207  110.354433
# 201903   99.831365  100.966480   74.273981   84.755852  129.183434
# 201904   95.224058   85.414640  119.507187   91.554333  126.350291
# 201905   95.170942   94.971679  176.356703   80.738028  143.264451
# 201906   97.837553  109.558078  120.563215   97.209803  143.421364
# 201907   97.466547  100.919888   93.282488   78.389300  144.548854
# 201908  113.029949  103.101071   74.449985   94.782402  145.285767
# 201909  104.816222   97.054467   84.834262  101.243155  143.375391
# 201910   88.822595   90.566510   40.481079   72.833703  144.228093
# 201911   91.722657   82.687356   61.601643   82.548221  134.215215
# 201912  100.025969   91.110797  147.491933   84.160069  136.891077
# 202001  113.926810   93.556413   55.617483  106.343972  134.115702
#
# catm       바디/헤어용품       뷰티소품         빙과류          빵류        생활용품        신선식품  \
# 201901  123.402292  72.578396   67.233311  112.092340  101.262282  117.382902
# 201902   80.209887  70.408716   74.679920   93.130189   88.412436   96.874609
# 201903   86.816300  82.202584   74.811717  112.942321  104.941775  104.294700
# 201904   90.300217  67.264532   78.662935  105.543371   94.024466   98.019807
# 201905   85.489742  79.862538  112.233807  104.824794  100.326114   98.917397
# 201906   85.277692  81.166767  138.313360  104.391157  101.786212   97.243328
# 201907   80.470438  85.370088  149.249926  102.259935  103.538866   94.084585
# 201908  113.674562  73.660836  152.141928  105.582221  105.699025  104.610704
# 201909  115.095218  72.789265   86.332441   96.624875   96.583047  105.516446
# 201910   71.184031  68.159119   67.083184   94.286073   90.478234   83.270644
# 201911   77.288035  65.733606   56.008982  103.189274   87.560136   80.424688
# 201912   84.244687  72.834095   64.573283  117.947815   86.194585   87.737206
# 202001  126.941389  83.475121   65.801776  103.251771   81.922764  106.285153
#
# catm       애완동물용품        유제품류          음료         제과류          주류         화장품
# 201901  90.613278   99.932399   95.525036   98.434326  104.588828  104.882519
# 201902  86.692108   89.308358   84.031689   99.899524   93.363184   81.691496
# 201903  96.404626  105.774862   94.838410  110.844999   95.855243   90.176158
# 201904  86.989560   98.680470   96.685220   98.216421   89.179150   81.120077
# 201905  93.256546   99.210705  102.481307   95.006752   96.452907  100.113399
# 201906  90.613471  100.539727  103.585112   92.998562   99.771911   85.915858
# 201907  92.264421   99.625784  103.845536   88.616953   95.117312   77.201941
# 201908  96.293114  103.901384  108.517393   91.583795  103.361500   73.454747
# 201909  89.356496   96.688838   99.478281   88.028708  102.650377   81.905452
# 201910  83.468812   94.479951   90.679280   97.239766   84.496417   67.194986
# 201911  82.268869   88.034698   87.446186   96.809018   84.492056   74.557498
# 201912  87.715400   92.561467   87.602473   95.376216  102.942833   72.688013
# 202001  76.344795   89.356392   92.974325   91.054355   98.691295   86.056387

# %%
index_c
# Out:
# catm         가공식품     건강관리용품      기타화장품       기호식품          담배    바디/헤어용품  \
# 202002  88.774395  95.656201  50.689352  72.851551  129.355111  68.833796
# 202003  95.290605  76.309547  27.808742  64.381990  142.024717  59.021617
# 202004  90.714777  76.023029   0.000000  72.007818  137.172340  56.472083
# 202005  76.879313  77.570563   0.000000  46.895471  129.246454  54.426671
#
# catm         뷰티소품        빙과류         빵류       생활용품       신선식품     애완동물용품  \
# 202002  55.076994  76.079279  85.578776  84.143044  89.626632  59.870766
# 202003  68.370350  82.957975  83.899685  83.712400  93.844744  62.434366
# 202004  43.637997  90.295904  77.830148  71.413559  86.224476  60.239869
# 202005  52.419825  82.198351  64.994579  70.461496  78.252591  60.617692
#
# catm         유제품류         음료        제과류         주류        화장품
# 202002  91.196513  76.779929  95.336665  84.281027  61.453200
# 202003  99.437938  78.561371  90.035850  94.177131  56.146139
# 202004  91.581680  79.094790  80.494625  94.809981  48.689371
# 202005  82.668203  86.186127  71.992427  89.562500  52.956144

# %%
a = index_b.mean()
a
# 담배, 빵류, 가공식품 / 뷰티소품, 화장품, 애완동물,
# Out:
# catm
# 가공식품       100.444871
# 건강관리용품      95.043669
# 기타화장품       90.818422
# 기호식품        92.186517
# 담배         135.890504
# 바디/헤어용품     93.876499
# 뷰티소품        75.038897
# 빙과류         91.317428
# 빵류         104.312780
# 생활용품        95.594611
# 신선식품        98.050936
# 애완동물용품      88.637038
# 유제품류        96.776541
# 음료          95.976173
# 제과류         95.700723
# 주류          96.227924
# 화장품         82.842964
# dtype: float64

# %%
b = index_c.mean()
b 
# 담베, 유제품류, 주류 / 뷰티소품, 애완동물용품, 화장품
# Out:
# catm
# 가공식품        87.914773
# 건강관리용품      81.389835
# 기타화장품       19.624523
# 기호식품        64.034208
# 담배         134.449655
# 바디/헤어용품     59.688542
# 뷰티소품        54.876292
# 빙과류         82.882877
# 빵류          78.075797
# 생활용품        77.432625
# 신선식품        86.987111
# 애완동물용품      60.790673
# 유제품류        91.221084
# 음료          80.155554
# 제과류         84.464892
# 주류          90.707660
# 화장품         54.811214
# dtype: float64

# %%
a = pd.DataFrame(a)
a
# Out:
#                   0
# catm
# 가공식품      99.321376
# 건강관리용품    95.167607
# 기타화장품     93.751833
# 기호식품      91.006729
# 담배       136.038404
# 바디/헤어용품   91.121092
# 뷰티소품      74.335879
# 빙과류       93.443733
# 빵류       104.401197
# 생활용품      96.733931
# 신선식품      97.364751
# 애완동물용품    89.661392
# 유제품류      97.394887
# 음료        96.226327
# 제과류       96.087920
# 주류        96.022643
# 화장품       82.575179

# %%
b = pd.DataFrame(b)
b
# Out:
#                   0
# catm
# 가공식품      93.117180
# 건강관리용품    83.823151
# 기타화장품     26.823115
# 기호식품      72.496160
# 담배       134.382865
# 바디/헤어용품   73.139111
# 뷰티소품      60.596057
# 빙과류       79.466657
# 빵류        83.110992
# 생활용품      78.330653
# 신선식품      90.846719
# 애완동물용품    63.901497
# 유제품류      90.848145
# 음료        82.719308
# 제과류       85.782784
# 주류        92.304387
# 화장품       61.060248

# %%
b.sort_index
# Out:
# <bound method Series.sort_index of catm
# 가공식품        93.117180
# 건강관리용품      83.823151
# 기타화장품       26.823115
# 기호식품        72.496160
# 담배         134.382865
# 바디/헤어용품     73.139111
# 뷰티소품        60.596057
# 빙과류         79.466657
# 빵류          83.110992
# 생활용품        78.330653
# 신선식품        90.846719
# 애완동물용품      63.901497
# 유제품류        90.848145
# 음료          82.719308
# 제과류         85.782784
# 주류          92.304387
# 화장품         61.060248
# dtype: float64>

# %%
index_F = masking(index_data, age=['all'], gender='F')
index_F.head()
# Out:
# catm          가공식품      건강관리용품       기타화장품        기호식품          담배  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  113.074273   91.946143   63.700935  132.649466  123.189379
# 201902   90.216966   89.546038   69.757009   94.279605  105.914849
# 201903  100.483802   98.559290   79.401869   85.588625  120.638457
# 201904   96.205568   81.876653  131.663551   90.802594  115.639387
#
# catm       바디/헤어용품        뷰티소품         빙과류          빵류        생활용품  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  102.167845   74.300182   67.362522  112.635499   98.777456
# 201902   84.605565   72.893461   74.352306   92.726149   88.066629
# 201903   93.160065   82.927278   73.001074  113.367539  104.841541
# 201904   81.554572   66.843472   77.998036  106.422318   93.682321
#
# catm          신선식품      애완동물용품        유제품류          음료         제과류  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  112.739839   90.470429   99.789354   91.293754   98.278658
# 201902   96.502265   85.846692   88.903217   85.476464  101.471419
# 201903  104.837691   94.598078  105.247848   94.634323  107.262716
# 201904   99.334804   86.243418   98.935837   95.262910   97.884829
#
# catm            주류         화장품
# 0       100.000000  100.000000
# 201901  102.103300  109.342915
# 201902   92.111997   83.786131
# 201903   94.387221   92.513698
# 201904   87.672850   81.156266

# %%
index_M = masking(index_data, age=['all'], gender='M')
index_M.head()
# Out:
# catm          가공식품      건강관리용품       기타화장품        기호식품          담배  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  129.746600   95.046828   72.752044  126.827903  138.313000
# 201902   90.664768   97.196765   54.768392   89.798054  114.150076
# 201903   98.064744  104.768471   55.585831   82.787576  136.489003
# 201904   92.566398   91.002649   75.204360   93.331084  135.507629
#
# catm       바디/헤어용품        뷰티소품         빙과류          빵류        생활용품  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  165.475177   66.737076   66.929967  110.800798  107.872666
# 201902   71.500507   61.978986   75.449050   94.090930   89.332388
# 201903   74.247078   79.743992   79.062515  111.931224  105.208426
# 201904  107.628405   68.693017   80.223900  103.453382   94.934673
#
# catm          신선식품      애완동물용품        유제품류          음료         제과류  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  131.198941   91.082428  100.329357  103.473275   98.812639
# 201902   97.982565   89.468667   90.432648   81.317755   96.079411
# 201903  102.678959  102.337782  107.237355   95.221776  119.550871
# 201904   94.106861   89.440079   97.971811   99.356954   99.022275
#
# catm            주류         화장품
# 0       100.000000  100.000000
# 201901  109.149889   92.731584
# 201902   95.659170   75.985324
# 201903   98.549133   83.808271
# 201904   91.943282   81.021490

# %%
index_F_b = index_F[1:14]
index_F_c = index_F[14:]
index_M_b = index_M[1:14]
index_M_c = index_M[14:]

# %%
index_F_b.mean()
# 담배, 빵, 가공식품  / 뷰티, 화장, 애완
# Out:
# catm
# 가공식품        99.869468
# 건강관리용품      93.544086
# 기타화장품       92.773544
# 기호식품        92.753857
# 담배         125.979452
# 바디/헤어용품     94.307204
# 뷰티소품        75.248393
# 빙과류         90.827611
# 빵류         104.428332
# 생활용품        94.452807
# 신선식품        97.408253
# 애완동물용품      87.937819
# 유제품류        96.544894
# 음료          95.667760
# 제과류         94.444811
# 주류          94.888422
# 화장품         84.170016
# dtype: float64

# %%
index_F_c.mean()
# 담배, 유제품, 주류 / 뷰티, 화장품, 애완동물
# Out:
# catm
# 가공식품        88.263726
# 건강관리용품      81.682213
# 기타화장품       20.130841
# 기호식품        60.416879
# 담배         126.566133
# 바디/헤어용품     63.340956
# 뷰티소품        51.837169
# 빙과류         83.340191
# 빵류          77.557224
# 생활용품        76.175978
# 신선식품        87.165413
# 애완동물용품      60.360724
# 유제품류        90.490425
# 음료          80.451997
# 제과류         81.862235
# 주류          89.543802
# 화장품         54.331748
# dtype: float64

# %%
index_M_b.mean()
# 담배, 빵, 가공식품 / 뷰티, 화장, 기호식품
# Out:
# catm
# 가공식품       102.002904
# 건강관리용품      97.412157
# 기타화장품       83.693146
# 기호식품        90.845597
# 담배         144.364004
# 바디/헤어용품     93.023123
# 뷰티소품        74.328163
# 빙과류         92.467359
# 빵류         104.038015
# 생활용품        98.632150
# 신선식품        99.963323
# 애완동물용품      90.933448
# 유제품류        97.419374
# 음료          96.555510
# 제과류         98.752912
# 주류          98.685974
# 화장품         79.227830
# dtype: float64

# %%
index_M_c.mean()
# 담배, 유제품류, 주류 / 화장품, 애완동물, 뷰티소품
# Out:
# catm
# 가공식품        86.969903
# 건강관리용품      80.928045
# 기타화장품       17.779292
# 기호식품        72.583844
# 담배         141.189711
# 바디/헤어용품     52.451829
# 뷰티소품        65.186798
# 빙과류         81.809255
# 빵류          79.308876
# 생활용품        80.775682
# 신선식품        86.456549
# 애완동물용품      62.202733
# 유제품류        93.248703
# 음료          79.598702
# 제과류         90.790019
# 주류          92.843394
# 화장품         56.117366
# dtype: float64

# %%
index_20 = masking(index_data, age=['20'], gender='all')
index_20.head()
# Out:
# catm          가공식품      건강관리용품       기타화장품        기호식품          담배  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  122.859801   98.670511   41.832669  118.286838  166.891223
# 201902  102.014892  111.490767   92.031873  114.880399  108.651564
# 201903  115.312518  115.283716   62.151394  107.338173  138.869177
# 201904  111.392985  113.998616  182.868526  102.815697  118.276137
#
# catm       바디/헤어용품        뷰티소품         빙과류          빵류        생활용품  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  164.058751   70.260761   80.103468  123.895591  102.453983
# 201902   99.200059   67.187301   80.171498  105.237991   98.671580
# 201903  101.661232   76.200306   89.053525  125.678208  114.367495
# 201904   97.972001   65.101254   95.152017  124.377655  106.215982
#
# catm          신선식품      애완동물용품        유제품류          음료         제과류  \
# 0       100.000000  100.000000  100.000000  100.000000  100.000000
# 201901  126.137499   88.862636  109.569379  104.339483  105.150963
# 201902  116.893034   94.055504   99.893263   96.343008  116.509748
# 201903  114.534760   98.514507  117.150449  104.194042  118.403511
# 201904  107.715292   94.415973  111.666717  106.390111  105.840330
#
# catm            주류         화장품
# 0       100.000000  100.000000
# 201901  112.524956   95.712394
# 201902  102.727206   90.557941
# 201903  109.020890   91.659425
# 201904   99.940400   78.623060

# %%
index_20_b = index_20[1:14]
index_20_c = index_20[14:]

# %%
index_20_c.mean()
# 담배, 주류, 유제품 / 뷰티소품, 기호식품, 애완동물
# Out:
# catm
# 가공식품       111.943428
# 건강관리용품     103.294377
# 기타화장품       24.203187
# 기호식품        71.989105
# 담배         149.614384
# 바디/헤어용품     79.154079
# 뷰티소품        52.204667
# 빙과류         89.308440
# 빵류          94.300223
# 생활용품        92.351538
# 신선식품       112.868014
# 애완동물용품      74.853764
# 유제품류       112.948741
# 음료          96.634294
# 제과류         90.926656
# 주류         117.436350
# 화장품         78.588753
# dtype: float64

# %%
index_20_b.mean()
# 담배, 빵, 가공식품 / 뷰티소품, 애완동물, 빙과류
# Out:
# catm
# 가공식품       116.905646
# 건강관리용품     114.008872
# 기타화장품       91.664113
# 기호식품       110.367700
# 담배         147.240727
# 바디/헤어용품    108.089107
# 뷰티소품        74.132094
# 빙과류        102.753295
# 빵류         121.233878
# 생활용품       109.561108
# 신선식품       113.777306
# 애완동물용품      98.747807
# 유제품류       110.167590
# 음료         111.144289
# 제과류        103.914638
# 주류         112.046530
# 화장품        107.442312
# dtype: float64

# %%
index_30 = masking(index_data, age=['30'], gender='all')
index_30_b = index_30[1:14]
index_30_c = index_30[14:]

# %%
index_30_b.mean()
# 담배, 빵류, 가공식품 / 뷰ㅌ소품, 화장품, 애완동물
# Out:
# catm
# 가공식품       101.503934
# 건강관리용품      86.223227
# 기타화장품       96.193013
# 기호식품        93.011323
# 담배         134.272799
# 바디/헤어용품     87.395287
# 뷰티소품        67.834612
# 빙과류         94.526406
# 빵류         110.556307
# 생활용품        96.485755
# 신선식품        98.178799
# 애완동물용품      87.149373
# 유제품류        96.829153
# 음료          98.756433
# 제과류         98.947153
# 주류          94.980947
# 화장품         76.427737
# dtype: float64

# %%
index_30_c.mean()
# Out:
# catm
# 가공식품        85.615917
# 건강관리용품      71.114277
# 기타화장품       18.737271
# 기호식품        59.730751
# 담배         130.726180
# 바디/헤어용품     50.822544
# 뷰티소품        39.546110
# 빙과류         87.159676
# 빵류          76.839354
# 생활용품        68.999574
# 신선식품        82.714558
# 애완동물용품      58.609748
# 유제품류        83.868691
# 음료          80.818195
# 제과류         81.566072
# 주류          89.522232
# 화장품         46.285881
# dtype: float64

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import wilcoxon

# %%
index_summarise = masking(index_data, age=['all'], gender='all')

index_pivot_bf = index_summarise.iloc[1:6, :]['담배']
index_pivot_af = index_summarise.iloc[-5:, :]['담배']

# %%
mannwhitneyu(index_pivot_bf, index_pivot_af)
# Out:
# MannwhitneyuResult(statistic=7.0, pvalue=0.1481349357421432)

# %%
index_summarise = masking(index_data, age=['20'], gender='all')

index_pivot_bf = index_summarise.iloc[1:6, :]['주류']
index_pivot_af = index_summarise.iloc[-5:, :]['주류']

# %%
mannwhitneyu(index_pivot_bf, index_pivot_af)
# Out:
# MannwhitneyuResult(statistic=3.0, pvalue=0.030051402969433157)

# %%
index_pivot_bf
# Out:
# 201901    112.524956
# 201902    102.727206
# 201903    109.020890
# 201904     99.940400
# 201905    110.150093
# 201906    118.338778
# 201907    107.750114
# 201908    118.158304
# 201909    115.654340
# 201910     96.095961
# 201911    102.319566
# 201912    144.664773
# Name: 주류, dtype: float64

# %%
index_pivot_af
# Out:
# 202001    119.259512
# 202002    108.981367
# 202003    123.635576
# 202004    120.644840
# 202005    116.483616
# Name: 주류, dtype: float64

# %%
index_summarise = masking(index_data, age=['20'], gender='all')
index_summarise1 = masking(index_data, age=['30'], gender='all')
index_summarise2 = masking(index_data, age=['40'], gender='all')
index_summarise3 = masking(index_data, age=['50'], gender='all')
index_summarise4 = masking(index_data, age=['60'], gender='all')

index_pivot_af = index_summarise.iloc[-5:, :]['주류']
index_pivot1_af = index_summarise1.iloc[-5:, :]['주류']
index_pivot2_af = index_summarise2.iloc[-5:, :]['주류']
index_pivot3_af = index_summarise3.iloc[-5:, :]['주류']
index_pivot4_af = index_summarise4.iloc[-5:, :]['주류']
df = pd.DataFrame([index_pivot_af, index_pivot1_af, index_pivot2_af, index_pivot3_af, index_pivot4_af],
                 index=['20대', '30대', '40대', '50대', '60대'])

# %%
df = df.T
df
# Out:
#                20대        30대        40대         50대         60대
# 202001  119.259512  93.898794  93.128340  103.613726  108.702465
# 202002  108.981367  83.849091  83.001643   83.442333   80.301130
# 202003  123.635576  93.935931  90.395704   93.936841   94.814359
# 202004  120.644840  93.351320  92.738279   94.282753   94.660006
# 202005  116.483616  86.952587  85.142315   90.477468   96.406558

# %%
stats.f_oneway(df['20대'], df['30대'], df['40대'], df['50대'], df['60대'])
# Out:
# F_onewayResult(statistic=15.338646049178195, pvalue=6.886843397520028e-06)

# %%
posthoc = pairwise_tukeyhsd(df['value'], df['variable'], alpha = 0.05)
print(posthoc)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#    20대    30대 -27.4034  0.001 -40.2018  -14.605   True
#    20대    40대 -28.9197  0.001 -41.7181 -16.1213   True
#    20대    50대 -24.6504  0.001 -37.4488  -11.852   True
#    20대    60대 -22.8241  0.001 -35.6225 -10.0257   True
#    30대    40대  -1.5163    0.9 -14.3147  11.2821  False
#    30대    50대   2.7531    0.9 -10.0453  15.5515  False
#    30대    60대   4.5794 0.7981   -8.219  17.3778  False
#    40대    50대   4.2694 0.8372   -8.529  17.0678  False
#    40대    60대   6.0956 0.6069  -6.7028   18.894  False
#    50대    60대   1.8263    0.9 -10.9721  14.6247  False
# ------------------------------------------------------

# %%
fig = posthoc.plot_simultaneous()
# Out:
# C:\Users\cptas\anaconda3\lib\site-packages\statsmodels\sandbox\stats\multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))

# %%
df['value']
# Out:
# 0     119.259512
# 1     108.981367
# 2     123.635576
# 3     120.644840
# 4     116.483616
# 5      93.898794
# 6      83.849091
# 7      93.935931
# 8      93.351320
# 9      86.952587
# 10     93.128340
# 11     83.001643
# 12     90.395704
# 13     92.738279
# 14     85.142315
# 15    103.613726
# 16     83.442333
# 17     93.936841
# 18     94.282753
# 19     90.477468
# 20    108.702465
# 21     80.301130
# 22     94.814359
# 23     94.660006
# 24     96.406558
# Name: value, dtype: float64

# %%
df = pd.DataFrame(data = {'기간': ['202001','202002','202003','202004','202005'], '20대': [119.26, 108.98, 123.64, 120.64, 116.48], '30대': [93.9, 83.85, 93.94, 93.35, 86.95], '40대': [93.13, 83, 90.4, 92.74, 85.14], '50대': [103.61, 83.44, 93.94, 94.28, 90.48], '60대': [108.7, 80.3, 94.81, 94.66, 96.41]}, columns = ['기간', '20대', '30대', '40대', '50대', '60대'])
df
# Out:
#        기간     20대    30대    40대     50대     60대
# 0  202001  119.26  93.90  93.13  103.61  108.70
# 1  202002  108.98  83.85  83.00   83.44   80.30
# 2  202003  123.64  93.94  90.40   93.94   94.81
# 3  202004  120.64  93.35  92.74   94.28   94.66
# 4  202005  116.48  86.95  85.14   90.48   96.41

# %%
index_pivot_af
# Out:
# 202001    119.259512
# 202002    108.981367
# 202003    123.635576
# 202004    120.644840
# 202005    116.483616
# Name: 주류, dtype: float64

# %%
index_pivot1_af
# Out:
# 202001    93.898794
# 202002    83.849091
# 202003    93.935931
# 202004    93.351320
# 202005    86.952587
# Name: 주류, dtype: float64

# %%
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.sandbox.stats.multicomp import MultiComparison
import scipy.stats

# %%
stats.f_oneway(df['20대'], df['30대'], df['40대'], df['50대'], df['60대'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '20대'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-e14113f7705a> in <module>
# ----> 1 stats.f_oneway(df['20대'], df['30대'], df['40대'], df['50대'], df['60대'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: '20대'

# %%
posthoc = pairwise_tukeyhsd(df['20대'], df['30대'], df['40대'], df['50대'], df['60대'])
print(posthoc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d80bd0ec3aa9> in <module>
# ----> 1 posthoc = pairwise_tukeyhsd(df['20대'], df['30대'], df['40대'], df['50대'], df['60대'])
#       2 print(posthoc)
#
# TypeError: pairwise_tukeyhsd() takes from 2 to 3 positional arguments but 5 were given

# %%
plot_data = [df['20대'], df['30대'], df['40대'], df['50대'], df['60대']]
ax = plt.boxplot(plot_data)
plt.show()
